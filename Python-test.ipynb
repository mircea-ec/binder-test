# %%
print('Hello World!')
# Out:
# Hello World!

# %%
import time
time.sleep(3)

# %%
def say_hello(recipient):
    return 'Hello, {}!'.format(recipient)
say_hello('EOSC Eu Node')
# Out:
# 'Hello, EOSC Eu Node!'
